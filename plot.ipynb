# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
test = pd.read_csv("models/model_v3/test.csv")

# %%
test
# Out:
#      episode                  level  reward
# 0         25  SuperMarioBros-1-1-v0   632.0
# 1         50  SuperMarioBros-1-1-v0  1061.0
# 2         75  SuperMarioBros-1-1-v0   267.0
# 3        100  SuperMarioBros-1-1-v0   232.0
# 4        125  SuperMarioBros-1-1-v0   482.0
# ..       ...                    ...     ...
# 958    23975  SuperMarioBros-1-1-v0  1155.0
# 959    24000  SuperMarioBros-1-1-v0  1339.0
# 960    24025  SuperMarioBros-1-1-v0  1333.0
# 961    24050  SuperMarioBros-1-1-v0  1707.0
# 962    24075  SuperMarioBros-1-1-v0  1695.0
#
# [963 rows x 3 columns]

# %%
# Plot
plt.figure(figsize=(10, 5))
plt.plot(test['episode'], test['reward'])
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("Reward vs Episode")
plt.grid(True)
plt.show()

# %%
# Correlation Coefficients
print(f"Pearson: {test['episode'].corr(test['reward'])}")
print(f"Spearman: {test['episode'].corr(test['reward'], method='spearman')}")
# Out:
# Pearson: 0.5749024775198843
# Spearman: 0.5723564072578657

# %%
# Smoothed plot
test['smooth'] = test['reward'].rolling(window=20).mean()

plt.plot(test['episode'], test['smooth'])
plt.xlabel("Episode")
plt.ylabel("Smoothed Reward")
plt.title("Smoothed Reward Curve")
plt.show()
